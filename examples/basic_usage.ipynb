# %%
# %load_ext autoreload
# %autoreload 2

# %%
import intake
from intake_qcodes.catalog import QCodesCatalog
cat = QCodesCatalog('../data/qcodes_data.db')

# %%
cat.save('qcodes_catalog.yaml')

# %%
cat_copy = intake.open_catalog('qcodes_catalog.yaml')
# Out:
# ---------------------------------------------------------------------------
# ConstructorError                          Traceback (most recent call last)
# <ipython-input-5-e8f6c3f975ac> in <module>
# ----> 1 cat_copy = intake.open_catalog('qcodes_catalog.yaml')
#
# ~\.conda\envs\pyqt5\lib\site-packages\intake\__init__.py in open_catalog(uri, **kwargs)
#     159         raise ValueError('Unknown catalog driver (%s), supply one of: %s'
#     160                          % (driver, list(sorted(registry))))
# --> 161     return registry[driver](uri, **kwargs)
#     162
#     163
#
# ~\.conda\envs\pyqt5\lib\site-packages\intake\catalog\local.py in __init__(self, path, autoreload, **kwargs)
#     550         self.autoreload = autoreload  # set this to False if don't want reloads
#     551         self.filesystem = kwargs.pop('fs', None)
# --> 552         super(YAMLFileCatalog, self).__init__(**kwargs)
#     553
#     554     def _load(self, reload=False):
#
# ...
